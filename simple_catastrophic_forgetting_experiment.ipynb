# %%
from random import shuffle
import numpy as np
import tensorflow as tf

from graph.graph import Graph
from graph.module import *
from graph.sublayer import *
from l2l.training import training_setup, training

# %% [markdown]
# ## Create a very simple problem to solve

# %%
# A simple (deterministic) 1D problem
def simple_problem(batch_size, problem='mult'):
    x = np.random.rand(batch_size, 1) * 10
    if problem == 'mult' or problem == 'multiply':
        y = x * 5
        x = np.concatenate((x, np.ones_like(x)), axis=1)
    elif problem == 'square':
        y = np.multiply(x, x)
        x = np.concatenate((x, -1*np.ones_like(x)), axis=1)
    elif problem == 'sqrt':
        y = np.sqrt(x)
        x = np.concatenate((x, np.zeros_like(x)), axis=1)
    else:
        raise ValueError('Invalid problem type: {}'.format(problem))
    return (x, y)

# %% [markdown]
# ## The training function

# %%
def train(parameter_dict, MO_options, training_info, training_iters=10):
    # Callable data getter where you can pick the problem
    def data_getter(problem):
        def func(batch_size):
            return simple_problem(batch_size, problem=problem)
        return func

    def random_data_getter(problems):
        def func(batch_size):
            prob = problems[np.random.randint(0, len(problems))]
            return simple_problem(batch_size, problem=prob)
        return func


    with tf.Session() as sess:
        packed_vars = training_setup(sess,
                                     parameter_dict=parameter_dict,
                                     MO_options=MO_options,
                                     training_info=training_info,
                                     additional_train=True,
                                     summaries=None,#'graph',
                                     accuracy_func=None,
                                     optimizer_sharing='m',
                                     load_prev_meta_opt=None,
                                     save_optimizer=False)

        # Run a round of training for multiplication problem
        print('First Iteration: {}. Problem: {}.'.format(0, 'mult'))
        training(data_getter=data_getter('mult'),
                 data_getter_additional=random_data_getter(['mult']),
                 **packed_vars)

        '''# List of problems
        problems = ['mult', 'square', 'sqrt']

        # Run a round of training with a random problem
        for i in range(int(training_iters/3)):
            # Select problem to use
            current_p = np.random.randint(0, len(problems))
            prob = problems[current_p]
            a_probs = [p for j, p in enumerate(problems) if j != current_p]

            # Run training
            print('\n\n\nIteration: {}. Next problem: {}.'.format(i, prob))
            training(data_getter=data_getter(prob),
                     data_getter_additional=random_data_getter(a_probs),
                     **packed_vars)'''

        for i in range(int(training_iters/2)):
            print('\n\n\nIteration: {}. Next problem: {}.'.format(i*2+1, 'square'))
            training(data_getter=data_getter('square'),
                     data_getter_additional=data_getter('mult'),
                     **packed_vars)
            print('\n\n\nIteration: {}. Next problem: {}.'.format(i*2+2, 'mult'))
            training(data_getter=data_getter('mult'),
                     data_getter_additional=data_getter('square'),
                     **packed_vars)

# %% [markdown]
# ## Define parameters

# %%
parameter_dict = {
        'C': 1,
        'sublayer_type': 'AdditionSublayerModule',
        'hidden_size': 4, # Hidden size of each module (or # of filters if using conv)
        'gamma': 3., # Gamma is the strength of gating in Gatenet
        'M': 6, # The number of 'modules' in each layer of Gatenet
        'L': 2, # The number of layers
        'module_type': 'PerceptronModule' # The type of module used
}
MO_options = {
        'optimizer_type': 'CoordinateWiseLSTM', # Type of RNN used for the meta optimizer
        'second_derivatives': False,
        'rnn_layers': (3,3), # Hidden sizes of the layers in the RNN
        'len_unroll': 3,
        'w_ts': [0.33 for _ in range(3)], # Matches w_t in section 2 of Learning to Learn By GD by GD (https://arxiv.org/pdf/1606.04474.pdf)
        'lr': 0.001, # Multiply the output of the RNN
        'meta_lr': 0.005, # LR for the meta optimizer
        'additional_loss_scale': 1. # How to weight the 'additional' loss
}
training_info = {
        'batch_size': 16,
        'num_batches': 100,
        'print_every': 10
}

training_iters=10

# %% [markdown]
# ## Train

# %%
train(parameter_dict, MO_options, training_info, training_iters)
# Out:
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# TODO Implement _verify_scope
# First Iteration: 0. Problem: mult.
#
# Iteration: 0 , loss: 24.9484 , meta_l: 55.9783 , addi_l: 31.2611
# Predictions & Answers
# Pred: [ 0.30684626], Actual: [ 15.91762576] -- Input: [ 3.18352515  1.        ]
# Pred: [ 0.04947605], Actual: [ 46.40465069] -- Input: [ 9.28093014  1.        ]
# Pred: [ 0.04485606], Actual: [ 37.00725019] -- Input: [ 7.40145004  1.        ]
# Pred: [ 0.08111712], Actual: [ 24.86059217] -- Input: [ 4.97211843  1.        ]
# Pred: [ 0.13427126], Actual: [ 22.16477457] -- Input: [ 4.43295491  1.        ]
# Pred: [ 0.04503509], Actual: [ 33.45274685] -- Input: [ 6.69054937  1.        ]
# Pred: [ 0.07076903], Actual: [ 26.01589928] -- Input: [ 5.20317986  1.        ]
# Pred: [ 0.26860112], Actual: [ 11.01740495] -- Input: [ 2.20348099  1.        ]
# Pred: [ 0.00959654], Actual: [ 1.85197557] -- Input: [ 0.37039511  1.        ]
# Pred: [ 0.23526913], Actual: [ 13.67804767] -- Input: [ 2.73560953  1.        ]
#
# Iteration: 10 , loss: 17.3704 , meta_l: 44.3709 , addi_l: 27.0304
# Predictions & Answers
# Pred: [ 0.19882286], Actual: [ 10.94942749] -- Input: [ 2.1898855  1.       ]
# Pred: [ 0.24414003], Actual: [ 21.24468778] -- Input: [ 4.24893756  1.        ]
# Pred: [ 0.06041241], Actual: [ 29.38825558] -- Input: [ 5.87765112  1.        ]
# Pred: [ 0.03062809], Actual: [ 4.51302121] -- Input: [ 0.90260424  1.        ]
# Pred: [ 0.07871723], Actual: [ 7.0189457] -- Input: [ 1.40378914  1.        ]
# Pred: [ 0.00747492], Actual: [ 0.18802744] -- Input: [ 0.03760549  1.        ]
# Pred: [ 0.15722321], Actual: [ 8.88534393] -- Input: [ 1.77706879  1.        ]
# Pred: [ 0.06106865], Actual: [ 29.2165699] -- Input: [ 5.84331398  1.        ]
# Pred: [ 0.02867769], Actual: [ 4.34119349] -- Input: [ 0.8682387  1.       ]
# Pred: [ 0.05058287], Actual: [ 42.25418867] -- Input: [ 8.45083773  1.        ]
#
# Iteration: 20 , loss: 23.9356 , meta_l: 43.0914 , addi_l: 19.3977
# Predictions & Answers
# Pred: [ 0.06384455], Actual: [ 42.19256225] -- Input: [ 8.43851245  1.        ]
# Pred: [ 0.13694675], Actual: [ 8.83671124] -- Input: [ 1.76734225  1.        ]
# Pred: [ 0.0872818], Actual: [ 7.18732884] -- Input: [ 1.43746577  1.        ]
# Pred: [ 0.06294736], Actual: [ 38.93694996] -- Input: [ 7.78738999  1.        ]
# Pred: [ 0.0356342], Actual: [ 4.05830623] -- Input: [ 0.81166125  1.        ]
# Pred: [ 0.16879265], Actual: [ 11.0627974] -- Input: [ 2.21255948  1.        ]
# Pred: [ 0.06748533], Actual: [ 46.88382381] -- Input: [ 9.37676476  1.        ]
# Pred: [ 0.12144682], Actual: [ 24.6625973] -- Input: [ 4.93251946  1.        ]
# Pred: [ 0.62964553], Actual: [ 20.91102868] -- Input: [ 4.18220574  1.        ]
# Pred: [ 0.21806131], Actual: [ 16.34124001] -- Input: [ 3.268248  1.      ]
#
# Iteration: 30 , loss: 19.5892 , meta_l: 52.0575 , addi_l: 32.0779
# Predictions & Answers
# Pred: [ 0.14679244], Actual: [ 9.36820463] -- Input: [ 1.87364093  1.        ]
# Pred: [ 0.07896429], Actual: [ 6.02665177] -- Input: [ 1.20533035  1.        ]
# Pred: [ 0.09452118], Actual: [ 31.16291909] -- Input: [ 6.23258382  1.        ]
# Pred: [ 0.08761651], Actual: [ 6.55940714] -- Input: [ 1.31188143  1.        ]
# Pred: [ 0.25038907], Actual: [ 17.59736394] -- Input: [ 3.51947279  1.        ]
# Pred: [ 0.08656868], Actual: [ 36.73084304] -- Input: [ 7.34616861  1.        ]
# Pred: [ 0.15303729], Actual: [ 9.79832197] -- Input: [ 1.95966439  1.        ]
# Pred: [ 0.0887204], Actual: [ 32.9922652] -- Input: [ 6.59845304  1.        ]
# Pred: [ 0.22844183], Actual: [ 17.09321247] -- Input: [ 3.41864249  1.        ]
# Pred: [ 0.03425151], Actual: [ 0.23519726] -- Input: [ 0.04703945  1.        ]
#
# Iteration: 40 , loss: 25.2269 , meta_l: 51.1254 , addi_l: 26.1165
# Predictions & Answers
# Pred: [ 0.17858118], Actual: [ 26.93442458] -- Input: [ 5.38688492  1.        ]
# Pred: [ 0.13020207], Actual: [ 7.86118035] -- Input: [ 1.57223607  1.        ]
# Pred: [ 0.14538944], Actual: [ 29.31088935] -- Input: [ 5.86217787  1.        ]
# Pred: [ 0.17877351], Actual: [ 13.72981911] -- Input: [ 2.74596382  1.        ]
# Pred: [ 0.15400931], Actual: [ 9.3924747] -- Input: [ 1.87849494  1.        ]
# Pred: [ 0.21969527], Actual: [ 17.05041605] -- Input: [ 3.41008321  1.        ]
# Pred: [ 0.08150001], Actual: [ 4.53647838] -- Input: [ 0.90729568  1.        ]
# Pred: [ 2.91382623], Actual: [ 22.12337507] -- Input: [ 4.42467501  1.        ]
# Pred: [ 0.13384628], Actual: [ 30.92026707] -- Input: [ 6.18405341  1.        ]
# Pred: [ 0.13597481], Actual: [ 30.56492054] -- Input: [ 6.11298411  1.        ]
#
# Iteration: 50 , loss: 30.9566 , meta_l: 61.5384 , addi_l: 30.9448
# Predictions & Answers
# Pred: [ 0.19339791], Actual: [ 30.79788498] -- Input: [ 6.159577  1.      ]
# Pred: [ 0.1778937], Actual: [ 32.93742692] -- Input: [ 6.58748538  1.        ]
# Pred: [ 0.17062315], Actual: [ 37.81582572] -- Input: [ 7.56316514  1.        ]
# Pred: [ 0.17530321], Actual: [ 46.41901877] -- Input: [ 9.28380375  1.        ]
# Pred: [ 0.1749149], Actual: [ 33.83150162] -- Input: [ 6.76630032  1.        ]
# Pred: [ 0.17816389], Actual: [ 49.93976866] -- Input: [ 9.98795373  1.        ]
# Pred: [ 0.27250814], Actual: [ 18.57209923] -- Input: [ 3.71441985  1.        ]
# Pred: [ 0.1728912], Actual: [ 42.83587634] -- Input: [ 8.56717527  1.        ]
# Pred: [ 0.21370086], Actual: [ 15.18844828] -- Input: [ 3.03768966  1.        ]
# Pred: [ 0.64412475], Actual: [ 24.74612598] -- Input: [ 4.9492252  1.       ]
#
# Iteration: 60 , loss: 20.7663 , meta_l: 48.7447 , addi_l: 28.2159
# Predictions & Answers
# Pred: [ 0.84924853], Actual: [ 26.10715828] -- Input: [ 5.22143166  1.        ]
# Pred: [ 0.22014141], Actual: [ 9.37610775] -- Input: [ 1.87522155  1.        ]
# Pred: [ 0.15065211], Actual: [ 3.04189359] -- Input: [ 0.60837872  1.        ]
# Pred: [ 0.19458923], Actual: [ 7.2915052] -- Input: [ 1.45830104  1.        ]
# Pred: [ 0.13568127], Actual: [ 0.07837366] -- Input: [ 0.01567473  1.        ]
# Pred: [ 0.24763489], Actual: [ 46.11682253] -- Input: [ 9.22336451  1.        ]
# Pred: [ 0.19072255], Actual: [ 6.99983415] -- Input: [ 1.39996683  1.        ]
# Pred: [ 0.25759488], Actual: [ 15.05746121] -- Input: [ 3.01149224  1.        ]
# Pred: [ 0.30379933], Actual: [ 30.06923975] -- Input: [ 6.01384795  1.        ]
# Pred: [ 0.24591258], Actual: [ 38.97461241] -- Input: [ 7.79492248  1.        ]
#
# Iteration: 70 , loss: 22.823 , meta_l: 37.9267 , addi_l: 15.242
# Predictions & Answers
# Pred: [ 0.35509416], Actual: [ 45.11540419] -- Input: [ 9.02308084  1.        ]
# Pred: [ 0.35161239], Actual: [ 17.72765898] -- Input: [ 3.5455318  1.       ]
# Pred: [ 0.29435706], Actual: [ 10.98649995] -- Input: [ 2.19729999  1.        ]
# Pred: [ 0.30219433], Actual: [ 12.13825599] -- Input: [ 2.4276512  1.       ]
# Pred: [ 1.41345859], Actual: [ 25.66725822] -- Input: [ 5.13345164  1.        ]
# Pred: [ 0.22125976], Actual: [ 4.53644896] -- Input: [ 0.90728979  1.        ]
# Pred: [ 0.65609044], Actual: [ 28.9594459] -- Input: [ 5.79188918  1.        ]
# Pred: [ 0.42578483], Actual: [ 31.86538102] -- Input: [ 6.3730762  1.       ]
# Pred: [ 0.36540318], Actual: [ 37.30166771] -- Input: [ 7.46033354  1.        ]
# Pred: [ 1.71033049], Actual: [ 27.46305973] -- Input: [ 5.49261195  1.        ]
#
# Iteration: 80 , loss: 27.5327 , meta_l: 51.6191 , addi_l: 23.6281
# Predictions & Answers
# Pred: [ 4.78509426], Actual: [ 28.01114919] -- Input: [ 5.60222984  1.        ]
# Pred: [ 0.52343047], Actual: [ 42.46105683] -- Input: [ 8.49221137  1.        ]
# Pred: [ 0.40269375], Actual: [ 13.71703716] -- Input: [ 2.74340743  1.        ]
# Pred: [ 0.53367716], Actual: [ 39.99902671] -- Input: [ 7.99980534  1.        ]
# Pred: [ 0.38876921], Actual: [ 11.89884423] -- Input: [ 2.37976885  1.        ]
# Pred: [ 0.57013011], Actual: [ 36.21491717] -- Input: [ 7.24298343  1.        ]
# Pred: [ 0.66942108], Actual: [ 33.00470107] -- Input: [ 6.60094021  1.        ]
# Pred: [ 0.5116002], Actual: [ 20.68118575] -- Input: [ 4.13623715  1.        ]
# Pred: [ 1.57156825], Actual: [ 29.49453993] -- Input: [ 5.89890799  1.        ]
# Pred: [ 0.48308104], Actual: [ 19.67480601] -- Input: [ 3.9349612  1.       ]
#
# Iteration: 90 , loss: 21.2222 , meta_l: 48.9426 , addi_l: 27.9573
# Predictions & Answers
# Pred: [ 0.75359595], Actual: [ 49.18747436] -- Input: [ 9.83749487  1.        ]
# Pred: [ 0.43395215], Actual: [ 6.82653822] -- Input: [ 1.36530764  1.        ]
# Pred: [ 2.75689554], Actual: [ 28.48239104] -- Input: [ 5.69647821  1.        ]
# Pred: [ 1.00480008], Actual: [ 25.45310565] -- Input: [ 5.09062113  1.        ]
# Pred: [ 0.49253339], Actual: [ 10.65117434] -- Input: [ 2.13023487  1.        ]
# Pred: [ 0.75554216], Actual: [ 47.4769949] -- Input: [ 9.49539898  1.        ]
# Pred: [ 0.41239536], Actual: [ 2.86978407] -- Input: [ 0.57395681  1.        ]
# Pred: [ 1.07950616], Actual: [ 33.67128915] -- Input: [ 6.73425783  1.        ]
# Pred: [ 0.78476334], Actual: [ 41.40608416] -- Input: [ 8.28121683  1.        ]
# Pred: [ 0.87995696], Actual: [ 36.56609687] -- Input: [ 7.31321937  1.        ]
#
#
#
# Iteration: 1. Next problem: square.
#
# Iteration: 0 , loss: 37.9239 , meta_l: 67.2993 , addi_l: 29.7572
# Predictions & Answers
# Pred: [ 0.75954384], Actual: [ 96.03705075] -- Input: [ 9.79984953 -1.        ]
# Pred: [ 0.58669734], Actual: [ 16.56964388] -- Input: [ 4.07058274 -1.        ]
# Pred: [ 0.60745972], Actual: [ 22.75427193] -- Input: [ 4.77014381 -1.        ]
# Pred: [ 0.70886773], Actual: [ 66.27860957] -- Input: [ 8.14116758 -1.        ]
# Pred: [ 0.49366686], Actual: [ 0.03184472] -- Input: [ 0.17845089 -1.        ]
# Pred: [ 0.66361344], Actual: [ 44.17221531] -- Input: [ 6.64621812 -1.        ]
# Pred: [ 0.61690247], Actual: [ 25.88042179] -- Input: [ 5.08728039 -1.        ]
# Pred: [ 0.65927166], Actual: [ 42.27620026] -- Input: [ 6.50201509 -1.        ]
# Pred: [ 0.71576762], Actual: [ 70.02166848] -- Input: [ 8.3678951 -1.       ]
# Pred: [ 0.50536472], Actual: [ 1.58709332] -- Input: [ 1.25979892 -1.        ]
#
# Iteration: 10 , loss: 29.335 , meta_l: 56.1309 , addi_l: 25.4488
# Predictions & Answers
# Pred: [ 0.68809474], Actual: [ 5.46717741] -- Input: [ 2.33819961 -1.        ]
# Pred: [ 0.86271524], Actual: [ 45.29230905] -- Input: [ 6.7299561 -1.       ]
# Pred: [ 0.8453505], Actual: [ 39.86359342] -- Input: [ 6.31376222 -1.        ]
# Pred: [ 0.75453997], Actual: [ 16.77687758] -- Input: [ 4.09595869 -1.        ]
# Pred: [ 0.93534374], Actual: [ 71.45131792] -- Input: [ 8.45288814 -1.        ]
# Pred: [ 0.89593148], Actual: [ 56.56803974] -- Input: [ 7.52117276 -1.        ]
# Pred: [ 0.96979094], Actual: [ 85.34957897] -- Input: [ 9.23848359 -1.        ]
# Pred: [ 0.86092436], Actual: [ 44.71757553] -- Input: [ 6.68712012 -1.        ]
# Pred: [ 0.83558708], Actual: [ 36.95279917] -- Input: [ 6.07888141 -1.        ]
# Pred: [ 0.90528703], Actual: [ 59.95383282] -- Input: [ 7.74298604 -1.        ]
#
# Iteration: 20 , loss: 20.808 , meta_l: 44.186 , addi_l: 23.6439
# Predictions & Answers
# Pred: [ 0.99964428], Actual: [ 26.23736521] -- Input: [ 5.12224221 -1.        ]
# Pred: [ 0.93490481], Actual: [ 15.51045782] -- Input: [ 3.93833186 -1.        ]
# Pred: [ 0.82779205], Actual: [ 1.31335314] -- Input: [ 1.1460162 -1.       ]
# Pred: [ 0.86754912], Actual: [ 3.55389424] -- Input: [ 1.88517751 -1.        ]
# Pred: [ 0.86569929], Actual: [ 4.24486796] -- Input: [ 2.06030773 -1.        ]
# Pred: [ 1.23338604], Actual: [ 81.77052111] -- Input: [ 9.04270541 -1.        ]
# Pred: [ 0.96179438], Actual: [ 19.94143506] -- Input: [ 4.4655834 -1.       ]
# Pred: [ 0.9773038], Actual: [ 22.42822065] -- Input: [ 4.73584424 -1.        ]
# Pred: [ 0.84075594], Actual: [ 1.52847649] -- Input: [ 1.23631569 -1.        ]
# Pred: [ 0.91766065], Actual: [ 12.83527747] -- Input: [ 3.58263555 -1.        ]
#
# Iteration: 30 , loss: 29.1062 , meta_l: 50.1084 , addi_l: 21.6986
# Predictions & Answers
# Pred: [ 1.22444654], Actual: [ 1.95724393] -- Input: [ 1.39901534 -1.        ]
# Pred: [ 1.11488032], Actual: [ 6.03556963] -- Input: [ 2.45673963 -1.        ]
# Pred: [ 1.31278157], Actual: [ 32.74619852] -- Input: [ 5.72242942 -1.        ]
# Pred: [ 1.38315153], Actual: [ 43.89169456] -- Input: [ 6.62508072 -1.        ]
# Pred: [ 1.3895812], Actual: [ 44.97747589] -- Input: [ 6.70652487 -1.        ]
# Pred: [ 1.15237927], Actual: [ 12.20999118] -- Input: [ 3.49427978 -1.        ]
# Pred: [ 1.5814352], Actual: [ 82.38851785] -- Input: [ 9.0768121 -1.       ]
# Pred: [ 1.39968634], Actual: [ 46.70680126] -- Input: [ 6.83423743 -1.        ]
# Pred: [ 0.95783466], Actual: [ 0.17927469] -- Input: [ 0.42340842 -1.        ]
# Pred: [ 1.30143976], Actual: [ 31.07618549] -- Input: [ 5.57460182 -1.        ]
#
# Iteration: 40 , loss: 34.8632 , meta_l: 58.9107 , addi_l: 21.7667
# Predictions & Answers
# Pred: [ 1.54678035], Actual: [ 13.52636697] -- Input: [ 3.67782095 -1.        ]
# Pred: [ 2.0157063], Actual: [ 74.20034793] -- Input: [ 8.61396238 -1.        ]
# Pred: [ 1.75100708], Actual: [ 37.4452529] -- Input: [ 6.11925264 -1.        ]
# Pred: [ 2.09695578], Actual: [ 87.34000537] -- Input: [ 9.34558748 -1.        ]
# Pred: [ 1.72457731], Actual: [ 34.25604266] -- Input: [ 5.85286619 -1.        ]
# Pred: [ 1.54713953], Actual: [ 13.57901685] -- Input: [ 3.68497176 -1.        ]
# Pred: [ 2.07335448], Actual: [ 83.43170876] -- Input: [ 9.13409595 -1.        ]
# Pred: [ 1.07741082], Actual: [ 0.00036894] -- Input: [ 0.01920774 -1.        ]
# Pred: [ 1.07694376], Actual: [ 0.00031441] -- Input: [ 0.01773164 -1.        ]
# Pred: [ 1.89659357], Actual: [ 56.53381353] -- Input: [ 7.5188971 -1.       ]
#
# Iteration: 50 , loss: 29.6073 , meta_l: 61.3377 , addi_l: 20.4181
# Predictions & Answers
# Pred: [ 2.09779406], Actual: [ 11.38521793] -- Input: [ 3.37419886 -1.        ]
# Pred: [ 2.57078409], Actual: [ 64.09076794] -- Input: [ 8.00567099 -1.        ]
# Pred: [ 2.27706552], Actual: [ 34.59972321] -- Input: [ 5.88215294 -1.        ]
# Pred: [ 2.10284567], Actual: [ 16.97167227] -- Input: [ 4.11966895 -1.        ]
# Pred: [ 2.51987362], Actual: [ 2.80743118] -- Input: [ 1.67553907 -1.        ]
# Pred: [ 2.34757662], Actual: [ 41.2940709] -- Input: [ 6.42604629 -1.        ]
# Pred: [ 2.24051023], Actual: [ 31.17627806] -- Input: [ 5.58357216 -1.        ]
# Pred: [ 2.13401937], Actual: [ 20.82107048] -- Input: [ 4.56301112 -1.        ]
# Pred: [ 2.54843569], Actual: [ 61.67759973] -- Input: [ 7.85350875 -1.        ]
# Pred: [ 1.62637079], Actual: [ 0.6117092] -- Input: [ 0.7821184 -1.       ]
#
# Iteration: 60 , loss: 33.7953 , meta_l: 62.2632 , addi_l: 30.5393
# Predictions & Answers
# Pred: [ 3.78949642], Actual: [ 86.78301561] -- Input: [ 9.31574021 -1.        ]
# Pred: [ 3.08564401], Actual: [ 28.99569967] -- Input: [ 5.38476552 -1.        ]
# Pred: [ 3.90467882], Actual: [ 7.80367028] -- Input: [ 2.79350502 -1.        ]
# Pred: [ 3.05975938], Actual: [ 15.16371756] -- Input: [ 3.89406183 -1.        ]
# Pred: [ 3.45172811], Actual: [ 3.20262165] -- Input: [ 1.78958701 -1.        ]
# Pred: [ 3.10859942], Actual: [ 13.42804039] -- Input: [ 3.66442907 -1.        ]
# Pred: [ 3.6448462], Actual: [ 8.56965924] -- Input: [ 2.92739803 -1.        ]
# Pred: [ 3.31330323], Actual: [ 47.5666784] -- Input: [ 6.89686004 -1.        ]
# Pred: [ 3.23722458], Actual: [ 41.62018479] -- Input: [ 6.45137077 -1.        ]
# Pred: [ 3.03442001], Actual: [ 23.07375526] -- Input: [ 4.80351489 -1.        ]
#
# Iteration: 70 , loss: 32.2113 , meta_l: 58.1784 , addi_l: 21.188
# Predictions & Answers
# Pred: [ 2.00664258], Actual: [ 1.19662281] -- Input: [ 1.09390256 -1.        ]
# Pred: [ 4.52880096], Actual: [ 20.76543014] -- Input: [ 4.55691015 -1.        ]
# Pred: [ 1.84139574], Actual: [ 0.41075309] -- Input: [ 0.64090022 -1.        ]
# Pred: [ 4.66496372], Actual: [ 44.30433254] -- Input: [ 6.65614998 -1.        ]
# Pred: [ 5.45163059], Actual: [ 11.67695521] -- Input: [ 3.41715601 -1.        ]
# Pred: [ 4.88378096], Actual: [ 58.1343683] -- Input: [ 7.62458971 -1.        ]
# Pred: [ 4.91695881], Actual: [ 60.17516052] -- Input: [ 7.75726502 -1.        ]
# Pred: [ 4.51280642], Actual: [ 32.48135584] -- Input: [ 5.69924169 -1.        ]
# Pred: [ 1.66135693], Actual: [  9.62094154e-05] -- Input: [ 0.00980864 -1.        ]
# Pred: [ 4.58579922], Actual: [ 38.75401954] -- Input: [ 6.22527265 -1.        ]
#
# Iteration: 80 , loss: 32.1859 , meta_l: 55.3687 , addi_l: 23.5204
# Predictions & Answers
# Pred: [ 4.78114939], Actual: [ 5.05135321] -- Input: [ 2.24752157 -1.        ]
# Pred: [ 7.9622879], Actual: [ 56.28967847] -- Input: [ 7.50264476 -1.        ]
# Pred: [ 8.63125801], Actual: [ 23.57057379] -- Input: [ 4.85495353 -1.        ]
# Pred: [ 7.91941357], Actual: [ 33.91138367] -- Input: [ 5.82334815 -1.        ]
# Pred: [ 8.70993233], Actual: [ 95.60052375] -- Input: [ 9.77755203 -1.        ]
# Pred: [ 6.84925699], Actual: [ 6.85134407] -- Input: [ 2.61750722 -1.        ]
# Pred: [ 11.14871025], Actual: [ 16.40626385] -- Input: [ 4.05046465 -1.        ]
# Pred: [ 7.909163], Actual: [ 34.34750407] -- Input: [ 5.86067437 -1.        ]
# Pred: [ 17.59682083], Actual: [ 12.78378371] -- Input: [ 3.57544175 -1.        ]
# Pred: [ 8.38122749], Actual: [ 79.46045056] -- Input: [ 8.91405915 -1.        ]
#
# Iteration: 90 , loss: 26.1604 , meta_l: 47.1553 , addi_l: 22.2755
# Predictions & Answers
# Pred: [ 17.3480072], Actual: [ 95.86132125] -- Input: [ 9.79087949 -1.        ]
# Pred: [ 17.40416145], Actual: [ 99.3677098] -- Input: [ 9.96833536 -1.        ]
# Pred: [ 28.03544617], Actual: [ 16.15843458] -- Input: [ 4.01975554 -1.        ]
# Pred: [ 2.13443518], Actual: [ 0.10449248] -- Input: [ 0.32325297 -1.        ]
# Pred: [ 18.18776321], Actual: [ 51.55939047] -- Input: [ 7.18048678 -1.        ]
# Pred: [ 23.61438751], Actual: [ 33.64094273] -- Input: [ 5.80008127 -1.        ]
# Pred: [ 31.02472305], Actual: [ 27.94589924] -- Input: [ 5.28638811 -1.        ]
# Pred: [ 9.49290466], Actual: [ 9.17462449] -- Input: [ 3.02896426 -1.        ]
# Pred: [ 3.60181522], Actual: [ 2.86936536] -- Input: [ 1.69392011 -1.        ]
# Pred: [ 18.03813553], Actual: [ 53.08156178] -- Input: [ 7.28570942 -1.        ]
#
#
#
# Iteration: 2. Next problem: mult.
#
# Iteration: 0 , loss: 27.5606 , meta_l: 33.9663 , addi_l: 8.6778
# Predictions & Answers
# Pred: [ 7.44076443], Actual: [ 47.25902492] -- Input: [ 9.45180498  1.        ]
# Pred: [ 3.34163237], Actual: [ 30.78284873] -- Input: [ 6.15656975  1.        ]
# Pred: [ 3.56789517], Actual: [ 32.93040297] -- Input: [ 6.58608059  1.        ]
# Pred: [ 2.92739916], Actual: [ 25.50602778] -- Input: [ 5.10120556  1.        ]
# Pred: [ 4.39419556], Actual: [ 38.44211303] -- Input: [ 7.68842261  1.        ]
# Pred: [ 1.54477215], Actual: [ 2.77975374] -- Input: [ 0.55595075  1.        ]
# Pred: [ 4.06946611], Actual: [ 36.60426607] -- Input: [ 7.32085321  1.        ]
# Pred: [ 2.72476339], Actual: [ 21.87902499] -- Input: [ 4.375805  1.      ]
# Pred: [ 3.77094412], Actual: [ 34.56813582] -- Input: [ 6.91362716  1.        ]
# Pred: [ 2.59195185], Actual: [ 18.91656958] -- Input: [ 3.78331392  1.        ]
#
# Iteration: 10 , loss: 20.9535 , meta_l: 69.3005 , addi_l: 54.7109
# Predictions & Answers
# Pred: [ 4.02086401], Actual: [ 33.18757856] -- Input: [ 6.63751571  1.        ]
# Pred: [ 3.65567493], Actual: [ 29.77638649] -- Input: [ 5.9552773  1.       ]
# Pred: [ 2.99856329], Actual: [ 20.32854142] -- Input: [ 4.06570828  1.        ]
# Pred: [ 3.05814695], Actual: [ 21.45824134] -- Input: [ 4.29164827  1.        ]
# Pred: [ 2.80235338], Actual: [ 16.20267834] -- Input: [ 3.24053567  1.        ]
# Pred: [ 7.91188145], Actual: [ 48.40438225] -- Input: [ 9.68087645  1.        ]
# Pred: [ 2.65090275], Actual: [ 12.20372526] -- Input: [ 2.44074505  1.        ]
# Pred: [ 3.04773092], Actual: [ 21.2656877] -- Input: [ 4.25313754  1.        ]
# Pred: [ 3.14467049], Actual: [ 22.97912189] -- Input: [ 4.59582438  1.        ]
# Pred: [ 3.43475556], Actual: [ 27.21213365] -- Input: [ 5.44242673  1.        ]
#
# Iteration: 20 , loss: 24.3677 , meta_l: 51.6576 , addi_l: 29.1668
# Predictions & Answers
# Pred: [ 3.34920549], Actual: [ 20.48078954] -- Input: [ 4.09615791  1.        ]
# Pred: [ 4.40129757], Actual: [ 32.92721005] -- Input: [ 6.58544201  1.        ]
# Pred: [ 3.92248964], Actual: [ 6.97987884] -- Input: [ 1.39597577  1.        ]
# Pred: [ 5.49300241], Actual: [ 39.92377325] -- Input: [ 7.98475465  1.        ]
# Pred: [ 5.36809444], Actual: [ 39.27898733] -- Input: [ 7.85579747  1.        ]
# Pred: [ 6.62507677], Actual: [ 44.6468306] -- Input: [ 8.92936612  1.        ]
# Pred: [ 5.90232897], Actual: [ 41.84049468] -- Input: [ 8.36809894  1.        ]
# Pred: [ 2.95360708], Actual: [ 10.66047037] -- Input: [ 2.13209407  1.        ]
# Pred: [ 4.08238745], Actual: [ 30.05449351] -- Input: [ 6.0108987  1.       ]
# Pred: [ 6.9320569], Actual: [ 45.66545123] -- Input: [ 9.13309025  1.        ]
#
# Iteration: 30 , loss: 22.8036 , meta_l: 29.9605 , addi_l: 14.163
# Predictions & Answers
# Pred: [ 7.23563671], Actual: [ 45.81224926] -- Input: [ 9.16244985  1.        ]
# Pred: [ 5.46874332], Actual: [ 37.62798352] -- Input: [ 7.5255967  1.       ]
# Pred: [ 4.44242239], Actual: [ 29.82598791] -- Input: [ 5.96519758  1.        ]
# Pred: [ 3.68117499], Actual: [ 20.49855248] -- Input: [ 4.0997105  1.       ]
# Pred: [ 3.60796976], Actual: [ 19.33415188] -- Input: [ 3.86683038  1.        ]
# Pred: [ 3.25901675], Actual: [ 12.87970031] -- Input: [ 2.57594006  1.        ]
# Pred: [ 5.38590813], Actual: [ 37.11611465] -- Input: [ 7.42322293  1.        ]
# Pred: [ 7.00733185], Actual: [ 44.97440824] -- Input: [ 8.99488165  1.        ]
# Pred: [ 7.75633526], Actual: [ 47.55418017] -- Input: [ 9.51083603  1.        ]
# Pred: [ 5.83224773], Actual: [ 39.70126136] -- Input: [ 7.94025227  1.        ]
#
# Iteration: 40 , loss: 24.0776 , meta_l: 33.5352 , addi_l: 9.84626
# Predictions & Answers
# Pred: [ 6.0209136], Actual: [ 38.68813246] -- Input: [ 7.73762649  1.        ]
# Pred: [ 5.54436541], Actual: [ 35.67698245] -- Input: [ 7.13539649  1.        ]
# Pred: [ 3.57021809], Actual: [ 13.72914647] -- Input: [ 2.74582929  1.        ]
# Pred: [ 6.61442327], Actual: [ 41.86383048] -- Input: [ 8.3727661  1.       ]
# Pred: [ 3.93595934], Actual: [ 19.59006912] -- Input: [ 3.91801382  1.        ]
# Pred: [ 3.52754164], Actual: [ 11.96367242] -- Input: [ 2.39273448  1.        ]
# Pred: [ 5.16637802], Actual: [ 32.89617503] -- Input: [ 6.57923501  1.        ]
# Pred: [ 3.95324516], Actual: [ 19.8416018] -- Input: [ 3.96832036  1.        ]
# Pred: [ 7.48506737], Actual: [ 45.69458801] -- Input: [ 9.1389176  1.       ]
# Pred: [ 5.10625839], Actual: [ 32.41445302] -- Input: [ 6.4828906  1.       ]
#
# Iteration: 50 , loss: 20.5187 , meta_l: 32.6351 , addi_l: 12.2013
# Predictions & Answers
# Pred: [ 4.45521069], Actual: [ 22.1824406] -- Input: [ 4.43648812  1.        ]
# Pred: [ 6.28897381], Actual: [ 37.95107256] -- Input: [ 7.59021451  1.        ]
# Pred: [ 6.19173813], Actual: [ 37.34829288] -- Input: [ 7.46965858  1.        ]
# Pred: [ 5.50605679], Actual: [ 32.53792731] -- Input: [ 6.50758546  1.        ]
# Pred: [ 4.81151485], Actual: [ 26.24954259] -- Input: [ 5.24990852  1.        ]
# Pred: [ 5.89141178], Actual: [ 35.3719057] -- Input: [ 7.07438114  1.        ]
# Pred: [ 4.48689556], Actual: [ 22.57171876] -- Input: [ 4.51434375  1.        ]
# Pred: [ 14.06074333], Actual: [ 4.91828076] -- Input: [ 0.98365615  1.        ]
# Pred: [ 6.14665127], Actual: [ 37.06293557] -- Input: [ 7.41258711  1.        ]
# Pred: [ 4.12326717], Actual: [ 17.83469682] -- Input: [ 3.56693936  1.        ]
#
# Iteration: 60 , loss: 19.4932 , meta_l: 41.9119 , addi_l: 22.9174
# Predictions & Answers
# Pred: [ 4.999331], Actual: [ 24.16361849] -- Input: [ 4.8327237  1.       ]
# Pred: [ 3.30616951], Actual: [ 1.28948739] -- Input: [ 0.25789748  1.        ]
# Pred: [ 8.10522938], Actual: [ 45.06724809] -- Input: [ 9.01344962  1.        ]
# Pred: [ 4.32428312], Actual: [ 16.22189744] -- Input: [ 3.24437949  1.        ]
# Pred: [ 5.76629066], Actual: [ 6.52142077] -- Input: [ 1.30428415  1.        ]
# Pred: [ 8.31928635], Actual: [ 46.0105925] -- Input: [ 9.2021185  1.       ]
# Pred: [ 5.50391579], Actual: [ 29.02955588] -- Input: [ 5.80591118  1.        ]
# Pred: [ 7.61516762], Actual: [ 42.75579583] -- Input: [ 8.55115917  1.        ]
# Pred: [ 6.09535217], Actual: [ 33.72576504] -- Input: [ 6.74515301  1.        ]
# Pred: [ 7.3290534], Actual: [ 41.29556144] -- Input: [ 8.25911229  1.        ]
#
# Iteration: 70 , loss: 25.8245 , meta_l: 34.8607 , addi_l: 11.1512
# Predictions & Answers
# Pred: [ 8.80451393], Actual: [ 45.82459543] -- Input: [ 9.16491909  1.        ]
# Pred: [ 5.55574131], Actual: [ 25.48316859] -- Input: [ 5.09663372  1.        ]
# Pred: [ 5.02612638], Actual: [ 20.12849839] -- Input: [ 4.02569968  1.        ]
# Pred: [ 5.8560524], Actual: [ 28.14987703] -- Input: [ 5.62997541  1.        ]
# Pred: [ 8.51541901], Actual: [ 44.51805558] -- Input: [ 8.90361112  1.        ]
# Pred: [ 78.89302826], Actual: [ 3.0993891] -- Input: [ 0.61987782  1.        ]
# Pred: [ 7.65055418], Actual: [ 40.19150456] -- Input: [ 8.03830091  1.        ]
# Pred: [ 5.06146049], Actual: [ 20.50869813] -- Input: [ 4.10173963  1.        ]
# Pred: [ 5.31444788], Actual: [ 23.14284283] -- Input: [ 4.62856857  1.        ]
# Pred: [ 25.27923584], Actual: [ 3.57106233] -- Input: [ 0.71421247  1.        ]
#
# Iteration: 80 , loss: 23.6615 , meta_l: 40.2414 , addi_l: 16.8581
# Predictions & Answers
# Pred: [ 6.2692709], Actual: [ 27.5836503] -- Input: [ 5.51673006  1.        ]
# Pred: [ 5.20899296], Actual: [ 17.95885826] -- Input: [ 3.59177165  1.        ]
# Pred: [ 8.79909515], Actual: [ 5.01786031] -- Input: [ 1.00357206  1.        ]
# Pred: [ 5.92672586], Actual: [ 24.72119848] -- Input: [ 4.9442397  1.       ]
# Pred: [ 7.58014011], Actual: [ 36.56869107] -- Input: [ 7.31373821  1.        ]
# Pred: [ 5.47990227], Actual: [ 20.60368762] -- Input: [ 4.12073752  1.        ]
# Pred: [ 6.07224751], Actual: [ 25.96864959] -- Input: [ 5.19372992  1.        ]
# Pred: [ 8.68684006], Actual: [ 42.50215546] -- Input: [ 8.50043109  1.        ]
# Pred: [ 7.1417532], Actual: [ 33.85255145] -- Input: [ 6.77051029  1.        ]
# Pred: [ 7.13983345], Actual: [ 33.84010317] -- Input: [ 6.76802063  1.        ]
#
# Iteration: 90 , loss: 23.9985 , meta_l: 40.0449 , addi_l: 16.4375
# Predictions & Answers
# Pred: [ 6.82423735], Actual: [ 27.51053] -- Input: [ 5.502106  1.      ]
# Pred: [ 9.9836216], Actual: [ 44.96202823] -- Input: [ 8.99240565  1.        ]
# Pred: [ 7.46746922], Actual: [ 31.8758596] -- Input: [ 6.37517192  1.        ]
# Pred: [ 7.32333517], Actual: [ 30.94669209] -- Input: [ 6.18933842  1.        ]
# Pred: [ 7.68682766], Actual: [ 33.24141731] -- Input: [ 6.64828346  1.        ]
# Pred: [ 5.30587578], Actual: [ 11.38870917] -- Input: [ 2.27774183  1.        ]
# Pred: [ 8.42467499], Actual: [ 37.4614789] -- Input: [ 7.49229578  1.        ]
# Pred: [ 9.5681572], Actual: [ 43.11511712] -- Input: [ 8.62302342  1.        ]
# Pred: [ 11.03128433], Actual: [ 49.23568308] -- Input: [ 9.84713662  1.        ]
# Pred: [ 6.723351], Actual: [ 26.77096278] -- Input: [ 5.35419256  1.        ]
#
#
#
# Iteration: 3. Next problem: square.
#
# Iteration: 0 , loss: 15.3456 , meta_l: 33.8293 , addi_l: 18.8269
# Predictions & Answers
# Pred: [ 4.16504765], Actual: [ 0.02914587] -- Input: [ 0.17072162 -1.        ]
# Pred: [ 20.7427578], Actual: [ 28.91762863] -- Input: [ 5.37751138 -1.        ]
# Pred: [ 28.01647377], Actual: [ 52.69757027] -- Input: [ 7.25930921 -1.        ]
# Pred: [ 7.48147535], Actual: [ 1.75247005] -- Input: [ 1.32380892 -1.        ]
# Pred: [ 22.74316978], Actual: [ 34.98590098] -- Input: [ 5.91488808 -1.        ]
# Pred: [ 31.19182777], Actual: [ 64.42500978] -- Input: [ 8.02651916 -1.        ]
# Pred: [ 9.15897179], Actual: [ 3.53005515] -- Input: [ 1.8788441 -1.       ]
# Pred: [ 5.08290482], Actual: [ 0.27852197] -- Input: [ 0.52775181 -1.        ]
# Pred: [ 31.09853363], Actual: [ 64.06998838] -- Input: [ 8.00437308 -1.        ]
# Pred: [ 17.49999237], Actual: [ 19.96456389] -- Input: [ 4.46817232 -1.        ]
#
# Iteration: 10 , loss: 16.2176 , meta_l: 36.9311 , addi_l: 21.0279
# Predictions & Answers
# Pred: [ 42.45057297], Actual: [ 79.71570244] -- Input: [ 8.92836505 -1.        ]
# Pred: [ 9.85615158], Actual: [ 2.84496782] -- Input: [ 1.68670324 -1.        ]
# Pred: [ 8.91742134], Actual: [ 2.03958712] -- Input: [ 1.42814114 -1.        ]
# Pred: [ 10.82104683], Actual: [ 3.80795393] -- Input: [ 1.95139794 -1.        ]
# Pred: [ 44.69908142], Actual: [ 87.08751271] -- Input: [ 9.33206905 -1.        ]
# Pred: [ 45.86146545], Actual: [ 90.96994534] -- Input: [ 9.53781659 -1.        ]
# Pred: [ 6.61178493], Actual: [ 0.63064755] -- Input: [ 0.79413321 -1.        ]
# Pred: [ 36.87489319], Actual: [ 62.27069901] -- Input: [ 7.89117856 -1.        ]
# Pred: [ 7.64594603], Actual: [ 1.16216305] -- Input: [ 1.07803666 -1.        ]
# Pred: [ 19.98761368], Actual: [ 18.57040261] -- Input: [ 4.309339 -1.      ]
#
# Iteration: 20 , loss: 13.6839 , meta_l: 32.5672 , addi_l: 19.2859
# Predictions & Answers
# Pred: [ 56.02886581], Actual: [ 91.35972495] -- Input: [ 9.55822813 -1.        ]
# Pred: [ 19.1055336], Actual: [ 11.62603342] -- Input: [ 3.40969697 -1.        ]
# Pred: [ 37.61562729], Actual: [ 46.33055536] -- Input: [ 6.80665523 -1.        ]
# Pred: [ 15.96311855], Actual: [ 7.49354567] -- Input: [ 2.73743414 -1.        ]
# Pred: [ 42.65660095], Actual: [ 57.85655571] -- Input: [ 7.6063497 -1.       ]
# Pred: [ 31.71767044], Actual: [ 33.79364124] -- Input: [ 5.81322985 -1.        ]
# Pred: [ 23.97257996], Actual: [ 19.27029769] -- Input: [ 4.38979472 -1.        ]
# Pred: [ 12.94595051], Actual: [ 4.26381211] -- Input: [ 2.06490002 -1.        ]
# Pred: [ 6.69768524], Actual: [ 0.40365355] -- Input: [ 0.63533735 -1.        ]
# Pred: [ 26.60462952], Actual: [ 23.91986264] -- Input: [ 4.89079366 -1.        ]
#
# Iteration: 30 , loss: 10.8559 , meta_l: 25.4319 , addi_l: 14.8991
# Predictions & Answers
# Pred: [ 15.25739288], Actual: [ 4.61700559] -- Input: [ 2.14872185 -1.        ]
# Pred: [ 36.90372849], Actual: [ 32.33054094] -- Input: [ 5.68599516 -1.        ]
# Pred: [ 24.98151779], Actual: [ 14.94237898] -- Input: [ 3.86553735 -1.        ]
# Pred: [ 39.86660385], Actual: [ 37.19387154] -- Input: [ 6.09867785 -1.        ]
# Pred: [ 56.40420151], Actual: [ 67.08420426] -- Input: [ 8.19049475 -1.        ]
# Pred: [ 20.92946434], Actual: [ 10.09369882] -- Input: [ 3.1770582 -1.       ]
# Pred: [ 10.9479599], Actual: [ 1.76905555] -- Input: [ 1.33005848 -1.        ]
# Pred: [ 70.60237122], Actual: [ 95.53616228] -- Input: [ 9.77426019 -1.        ]
# Pred: [ 4.91169214], Actual: [ 0.00096751] -- Input: [ 0.03110481 -1.        ]
# Pred: [ 6.91842031], Actual: [ 0.3086545] -- Input: [ 0.55556682 -1.        ]
#
# Iteration: 40 , loss: 9.69071 , meta_l: 26.8044 , addi_l: 17.4172
# Predictions & Answers
# Pred: [ 38.02681351], Actual: [ 30.7164368] -- Input: [ 5.54224113 -1.        ]
# Pred: [ 69.0351181], Actual: [ 81.13022756] -- Input: [ 9.00723196 -1.        ]
# Pred: [ 17.06078339], Actual: [ 5.69544475] -- Input: [ 2.38651309 -1.        ]
# Pred: [ 56.42258835], Actual: [ 59.5077288] -- Input: [ 7.71412528 -1.        ]
# Pred: [ 13.81791496], Actual: [ 3.28159245] -- Input: [ 1.81151662 -1.        ]
# Pred: [ 44.2664032], Actual: [ 40.01633982] -- Input: [ 6.32584696 -1.        ]
# Pred: [ 12.88933945], Actual: [ 2.70109118] -- Input: [ 1.64349968 -1.        ]
# Pred: [ 5.34482527], Actual: [ 0.05012156] -- Input: [ 0.22387845 -1.        ]
# Pred: [ 4.85734749], Actual: [  9.16858310e-05] -- Input: [ 0.00957527 -1.        ]
# Pred: [ 64.19455719], Actual: [ 72.69185327] -- Input: [ 8.52595175 -1.        ]
#
# Iteration: 50 , loss: 8.61569 , meta_l: 27.2489 , addi_l: 18.8546
# Predictions & Answers
# Pred: [ 39.70542526], Actual: [ 30.70800892] -- Input: [ 5.54148075 -1.        ]
# Pred: [ 75.67585754], Actual: [ 83.76942454] -- Input: [ 9.15256382 -1.        ]
# Pred: [ 48.15258789], Actual: [ 42.36007297] -- Input: [ 6.50846164 -1.        ]
# Pred: [ 23.89289665], Actual: [ 11.65582738] -- Input: [ 3.41406318 -1.        ]
# Pred: [ 48.94880676], Actual: [ 43.4931263] -- Input: [ 6.59493186 -1.        ]
# Pred: [ 7.63246155], Actual: [ 0.42172309] -- Input: [ 0.6494021 -1.       ]
# Pred: [ 28.03094673], Actual: [ 16.1571588] -- Input: [ 4.01959685 -1.        ]
# Pred: [ 24.19875145], Actual: [ 11.97288212] -- Input: [ 3.46018527 -1.        ]
# Pred: [ 8.71516895], Actual: [ 0.72313508] -- Input: [ 0.85037349 -1.        ]
# Pred: [ 40.47153854], Actual: [ 31.73341985] -- Input: [ 5.63324239 -1.        ]
#
# Iteration: 60 , loss: 8.26152 , meta_l: 20.037 , addi_l: 11.8728
# Predictions & Answers
# Pred: [ 94.79657745], Actual: [ 99.80446333] -- Input: [ 9.99021838 -1.        ]
# Pred: [ 5.61879063], Actual: [ 0.04918145] -- Input: [ 0.22176892 -1.        ]
# Pred: [ 12.88126469], Actual: [ 2.33226427] -- Input: [ 1.52717526 -1.        ]
# Pred: [ 65.94656372], Actual: [ 61.02150936] -- Input: [ 7.81162655 -1.        ]
# Pred: [ 44.72391129], Actual: [ 33.78437154] -- Input: [ 5.8124325 -1.       ]
# Pred: [ 14.34587669], Actual: [ 3.14612796] -- Input: [ 1.77373278 -1.        ]
# Pred: [ 35.77010727], Actual: [ 23.1249774] -- Input: [ 4.80884367 -1.        ]
# Pred: [ 66.7179718], Actual: [ 62.0418373] -- Input: [ 7.8766641 -1.       ]
# Pred: [ 26.67451286], Actual: [ 13.30502198] -- Input: [ 3.64760496 -1.        ]
# Pred: [ 71.47033691], Actual: [ 68.35689787] -- Input: [ 8.26782304 -1.        ]
#
# Iteration: 70 , loss: 10.4583 , meta_l: 23.0341 , addi_l: 12.6603
# Predictions & Answers
# Pred: [ 45.52843475], Actual: [ 32.74722281] -- Input: [ 5.72251892 -1.        ]
# Pred: [ 13.57529831], Actual: [ 2.57807873] -- Input: [ 1.60563966 -1.        ]
# Pred: [ 5.62157631], Actual: [ 0.03743604] -- Input: [ 0.19348395 -1.        ]
# Pred: [ 51.65222168], Actual: [ 39.78319256] -- Input: [ 6.3073919 -1.       ]
# Pred: [ 45.82572937], Actual: [ 33.08525408] -- Input: [ 5.75197828 -1.        ]
# Pred: [ 96.94609833], Actual: [ 93.3128152] -- Input: [ 9.65985586 -1.        ]
# Pred: [ 51.90418243], Actual: [ 40.07552422] -- Input: [ 6.33052322 -1.        ]
# Pred: [ 23.02967072], Actual: [ 9.39269923] -- Input: [ 3.06475109 -1.        ]
# Pred: [ 16.25271797], Actual: [ 4.17094719] -- Input: [ 2.04228969 -1.        ]
# Pred: [ 5.46379566], Actual: [ 0.02311356] -- Input: [ 0.15203143 -1.        ]
#
# Iteration: 80 , loss: 13.1983 , meta_l: 24.1585 , addi_l: 10.9715
# Predictions & Answers
# Pred: [ 89.44455719], Actual: [ 76.2609009] -- Input: [ 8.73274876 -1.        ]
# Pred: [ 5.72109318], Actual: [ 0.03842425] -- Input: [ 0.19602105 -1.        ]
# Pred: [ 113.05858612], Actual: [ 99.86345574] -- Input: [ 9.99317046 -1.        ]
# Pred: [ 14.75725174], Actual: [ 3.07115748] -- Input: [ 1.75247182 -1.        ]
# Pred: [ 102.88918304], Actual: [ 89.82658159] -- Input: [ 9.47768862 -1.        ]
# Pred: [ 38.74298096], Actual: [ 23.54943339] -- Input: [ 4.85277584 -1.        ]
# Pred: [ 22.5410347], Actual: [ 8.49143884] -- Input: [ 2.91400735 -1.        ]
# Pred: [ 62.82188416], Actual: [ 48.59460817] -- Input: [ 6.9709833 -1.       ]
# Pred: [ 22.65891647], Actual: [ 8.58680261] -- Input: [ 2.93032466 -1.        ]
# Pred: [ 88.16321564], Actual: [ 74.95146933] -- Input: [ 8.65745166 -1.        ]
#
# Iteration: 90 , loss: 17.3459 , meta_l: 29.7881 , addi_l: 12.4289
# Predictions & Answers
# Pred: [ 25.24672699], Actual: [ 10.18141658] -- Input: [ 3.19083321 -1.        ]
# Pred: [ 49.19348145], Actual: [ 31.81185372] -- Input: [ 5.64019979 -1.        ]
# Pred: [ 87.76628113], Actual: [ 67.30358336] -- Input: [ 8.20387612 -1.        ]
# Pred: [ 9.17604923], Actual: [ 0.64659825] -- Input: [ 0.80411333 -1.        ]
# Pred: [ 55.88203812], Actual: [ 38.11207634] -- Input: [ 6.1734979 -1.       ]
# Pred: [ 115.91017914], Actual: [ 91.17931743] -- Input: [ 9.54878618 -1.        ]
# Pred: [ 17.07878304], Actual: [ 4.26603222] -- Input: [ 2.06543754 -1.        ]
# Pred: [ 49.77709198], Actual: [ 32.36168608] -- Input: [ 5.68873326 -1.        ]
# Pred: [ 42.18647385], Actual: [ 25.23443895] -- Input: [ 5.02338919 -1.        ]
# Pred: [ 32.9472847], Actual: [ 16.76839543] -- Input: [ 4.09492313 -1.        ]
#
#
#
# Iteration: 4. Next problem: mult.
#
# Iteration: 0 , loss: 11.2293 , meta_l: 34.379 , addi_l: 22.4045
# Predictions & Answers
# Pred: [ 13.77799416], Actual: [ 6.20968863] -- Input: [ 1.24193773  1.        ]
# Pred: [ 22.4767952], Actual: [ 38.497992] -- Input: [ 7.6995984  1.       ]
# Pred: [ 17.57491875], Actual: [ 28.40420373] -- Input: [ 5.68084075  1.        ]
# Pred: [ 21.75405884], Actual: [ 37.08659406] -- Input: [ 7.41731881  1.        ]
# Pred: [ 13.359519], Actual: [ 18.55714208] -- Input: [ 3.71142842  1.        ]
# Pred: [ 12.08205509], Actual: [ 11.09028381] -- Input: [ 2.21805676  1.        ]
# Pred: [ 24.05419922], Actual: [ 41.500664] -- Input: [ 8.3001328  1.       ]
# Pred: [ 19.35266495], Actual: [ 32.21434016] -- Input: [ 6.44286803  1.        ]
# Pred: [ 14.44857216], Actual: [ 3.21218545] -- Input: [ 0.64243709  1.        ]
# Pred: [ 13.71037674], Actual: [ 0.37958754] -- Input: [ 0.07591751  1.        ]
#
# Iteration: 10 , loss: 8.81502 , meta_l: 37.3218 , addi_l: 27.679
# Predictions & Answers
# Pred: [ 15.22044182], Actual: [ 1.26417917] -- Input: [ 0.25283583  1.        ]
# Pred: [ 15.89561081], Actual: [ 19.96678437] -- Input: [ 3.99335687  1.        ]
# Pred: [ 31.33703423], Actual: [ 47.16776851] -- Input: [ 9.4335537  1.       ]
# Pred: [ 29.74535942], Actual: [ 44.69813183] -- Input: [ 8.93962637  1.        ]
# Pred: [ 15.07985115], Actual: [ 0.94855949] -- Input: [ 0.1897119  1.       ]
# Pred: [ 13.55925369], Actual: [ 12.34160961] -- Input: [ 2.46832192  1.        ]
# Pred: [ 14.32648087], Actual: [ 16.2524736] -- Input: [ 3.25049472  1.        ]
# Pred: [ 14.79894447], Actual: [ 7.14864471] -- Input: [ 1.42972894  1.        ]
# Pred: [ 32.47373199], Actual: [ 48.8984765] -- Input: [ 9.7796953  1.       ]
# Pred: [ 14.83304214], Actual: [ 17.58430352] -- Input: [ 3.5168607  1.       ]
#
# Iteration: 20 , loss: 7.89028 , meta_l: 50.5692 , addi_l: 41.3278
# Predictions & Answers
# Pred: [ 27.46250534], Actual: [ 35.01442572] -- Input: [ 7.00288514  1.        ]
# Pred: [ 27.45565987], Actual: [ 35.00416167] -- Input: [ 7.00083233  1.        ]
# Pred: [ 33.83387756], Actual: [ 44.14170626] -- Input: [ 8.82834125  1.        ]
# Pred: [ 26.92253494], Actual: [ 34.2011377] -- Input: [ 6.84022754  1.        ]
# Pred: [ 38.0654335], Actual: [ 49.81210071] -- Input: [ 9.96242014  1.        ]
# Pred: [ 18.35826683], Actual: [ 20.10009513] -- Input: [ 4.02001903  1.        ]
# Pred: [ 17.04922676], Actual: [ 3.11364765] -- Input: [ 0.62272953  1.        ]
# Pred: [ 16.9389801], Actual: [ 2.547252] -- Input: [ 0.5094504  1.       ]
# Pred: [ 15.43844414], Actual: [ 11.31196181] -- Input: [ 2.26239236  1.        ]
# Pred: [ 34.96546173], Actual: [ 45.68460052] -- Input: [ 9.1369201  1.       ]
#
# Iteration: 30 , loss: 3.00549 , meta_l: 83.1788 , addi_l: 76.8641
# Predictions & Answers
# Pred: [ 27.12552261], Actual: [ 28.71072298] -- Input: [ 5.7421446  1.       ]
# Pred: [ 41.20510483], Actual: [ 46.69294776] -- Input: [ 9.33858955  1.        ]
# Pred: [ 19.85804939], Actual: [ 17.98384393] -- Input: [ 3.59676879  1.        ]
# Pred: [ 21.95715904], Actual: [ 21.29782694] -- Input: [ 4.25956539  1.        ]
# Pred: [ 33.11230087], Actual: [ 36.72754131] -- Input: [ 7.34550826  1.        ]
# Pred: [ 37.99982834], Actual: [ 42.84775666] -- Input: [ 8.56955133  1.        ]
# Pred: [ 24.99020195], Actual: [ 25.70001815] -- Input: [ 5.14000363  1.        ]
# Pred: [ 40.2072258], Actual: [ 45.50859887] -- Input: [ 9.10171977  1.        ]
# Pred: [ 37.36384964], Actual: [ 42.07000621] -- Input: [ 8.41400124  1.        ]
# Pred: [ 30.53403091], Actual: [ 33.35163574] -- Input: [ 6.67032715  1.        ]
#
# Iteration: 40 , loss: 6.83999 , meta_l: 138.385 , addi_l: 123.536
# Predictions & Answers
# Pred: [ 19.00971794], Actual: [ 2.4208699] -- Input: [ 0.48417398  1.        ]
# Pred: [ 26.82888412], Actual: [ 24.43061467] -- Input: [ 4.88612293  1.        ]
# Pred: [ 25.66856575], Actual: [ 22.96074036] -- Input: [ 4.59214807  1.        ]
# Pred: [ 19.08177567], Actual: [ 12.0155526] -- Input: [ 2.40311052  1.        ]
# Pred: [ 46.17298508], Actual: [ 46.76827212] -- Input: [ 9.35365442  1.        ]
# Pred: [ 19.24915314], Actual: [ 3.12815658] -- Input: [ 0.62563132  1.        ]
# Pred: [ 18.8806057], Actual: [ 10.53677001] -- Input: [ 2.107354  1.      ]
# Pred: [ 43.0725441], Actual: [ 43.45095666] -- Input: [ 8.69019133  1.        ]
# Pred: [ 38.8589325], Actual: [ 38.80154708] -- Input: [ 7.76030942  1.        ]
# Pred: [ 21.90596008], Actual: [ 17.88260524] -- Input: [ 3.57652105  1.        ]
#
# Iteration: 50 , loss: 5.49211 , meta_l: 102.25 , addi_l: 90.197
# Predictions & Answers
# Pred: [ 30.22804642], Actual: [ 28.24578545] -- Input: [ 5.64915709  1.        ]
# Pred: [ 20.20792007], Actual: [ 14.80731185] -- Input: [ 2.96146237  1.        ]
# Pred: [ 18.91648102], Actual: [ 9.6467514] -- Input: [ 1.92935028  1.        ]
# Pred: [ 19.02604294], Actual: [ 2.5939099] -- Input: [ 0.51878198  1.        ]
# Pred: [ 43.8651619], Actual: [ 43.70628597] -- Input: [ 8.74125719  1.        ]
# Pred: [ 25.39101791], Actual: [ 22.31852962] -- Input: [ 4.46370592  1.        ]
# Pred: [ 33.52164459], Actual: [ 32.15433718] -- Input: [ 6.43086744  1.        ]
# Pred: [ 18.96476364], Actual: [ 2.43618378] -- Input: [ 0.48723676  1.        ]
# Pred: [ 21.26776505], Actual: [ 16.6749316] -- Input: [ 3.33498632  1.        ]
# Pred: [ 28.10002136], Actual: [ 25.66443461] -- Input: [ 5.13288692  1.        ]
#
# Iteration: 60 , loss: 3.87554 , meta_l: 167.656 , addi_l: 210.148
# Predictions & Answers
# Pred: [ 18.74784088], Actual: [ 7.91002835] -- Input: [ 1.58200567  1.        ]
# Pred: [ 30.18731308], Actual: [ 28.64348075] -- Input: [ 5.72869615  1.        ]
# Pred: [ 45.17072296], Actual: [ 45.60486296] -- Input: [ 9.12097259  1.        ]
# Pred: [ 46.77534866], Actual: [ 47.31081665] -- Input: [ 9.46216333  1.        ]
# Pred: [ 18.63731956], Actual: [ 8.89263422] -- Input: [ 1.77852684  1.        ]
# Pred: [ 47.58795547], Actual: [ 48.16808422] -- Input: [ 9.63361684  1.        ]
# Pred: [ 34.6264801], Actual: [ 33.88558097] -- Input: [ 6.77711619  1.        ]
# Pred: [ 18.91746902], Actual: [ 3.25213262] -- Input: [ 0.65042652  1.        ]
# Pred: [ 35.15846634], Actual: [ 34.50085207] -- Input: [ 6.90017041  1.        ]
# Pred: [ 45.66302872], Actual: [ 46.13015767] -- Input: [ 9.22603153  1.        ]
#
# Iteration: 70 , loss: 4.03891 , meta_l: 562.978 , addi_l: 515.645
# Predictions & Answers
# Pred: [ 18.16727066], Actual: [ 10.42564009] -- Input: [ 2.08512802  1.        ]
# Pred: [ 30.70588684], Actual: [ 29.77241047] -- Input: [ 5.95448209  1.        ]
# Pred: [ 38.58913803], Actual: [ 38.91738452] -- Input: [ 7.7834769  1.       ]
# Pred: [ 29.68858719], Actual: [ 28.55288566] -- Input: [ 5.71057713  1.        ]
# Pred: [ 27.28634453], Actual: [ 25.64367656] -- Input: [ 5.12873531  1.        ]
# Pred: [ 27.792099], Actual: [ 26.25918338] -- Input: [ 5.25183668  1.        ]
# Pred: [ 18.56980324], Actual: [ 4.67828268] -- Input: [ 0.93565654  1.        ]
# Pred: [ 18.30583763], Actual: [ 7.55297657] -- Input: [ 1.51059531  1.        ]
# Pred: [ 40.96790695], Actual: [ 41.57273386] -- Input: [ 8.31454677  1.        ]
# Pred: [ 48.5196228], Actual: [ 49.73214923] -- Input: [ 9.94642985  1.        ]
#
# Iteration: 80 , loss: 3.96361 , meta_l: 232.445 , addi_l: 255.612
# Predictions & Answers
# Pred: [ 18.08285904], Actual: [ 5.39050953] -- Input: [ 1.07810191  1.        ]
# Pred: [ 25.86443138], Actual: [ 24.05168067] -- Input: [ 4.81033613  1.        ]
# Pred: [ 24.71548462], Actual: [ 22.64456914] -- Input: [ 4.52891383  1.        ]
# Pred: [ 24.66219521], Actual: [ 22.57864348] -- Input: [ 4.5157287  1.       ]
# Pred: [ 18.57530212], Actual: [ 13.40143749] -- Input: [ 2.6802875  1.       ]
# Pred: [ 33.44152451], Actual: [ 33.02801092] -- Input: [ 6.60560218  1.        ]
# Pred: [ 35.56515121], Actual: [ 35.46910549] -- Input: [ 7.0938211  1.       ]
# Pred: [ 34.56851578], Actual: [ 34.32788683] -- Input: [ 6.86557737  1.        ]
# Pred: [ 33.09410477], Actual: [ 32.62528965] -- Input: [ 6.52505793  1.        ]
# Pred: [ 17.81228065], Actual: [ 8.34320105] -- Input: [ 1.66864021  1.        ]
#
# Iteration: 90 , loss: 2.51416 , meta_l: 497.994 , addi_l: 490.843
# Predictions & Answers
# Pred: [ 35.06947708], Actual: [ 36.18978338] -- Input: [ 7.23795668  1.        ]
# Pred: [ 39.92870712], Actual: [ 41.77158388] -- Input: [ 8.35431678  1.        ]
# Pred: [ 39.68987274], Actual: [ 41.50097063] -- Input: [ 8.30019413  1.        ]
# Pred: [ 43.84201431], Actual: [ 46.15447915] -- Input: [ 9.23089583  1.        ]
# Pred: [ 17.04023552], Actual: [ 3.5636965] -- Input: [ 0.7127393  1.       ]
# Pred: [ 36.35937881], Actual: [ 37.68747757] -- Input: [ 7.53749551  1.        ]
# Pred: [ 26.98234177], Actual: [ 26.54115124] -- Input: [ 5.30823025  1.        ]
# Pred: [ 38.14733505], Actual: [ 39.74411937] -- Input: [ 7.94882387  1.        ]
# Pred: [ 38.31225967], Actual: [ 39.93271972] -- Input: [ 7.98654394  1.        ]
# Pred: [ 17.6477375], Actual: [ 13.03964606] -- Input: [ 2.60792921  1.        ]
#
#
#
# Iteration: 5. Next problem: square.
#
# Iteration: 0 , loss: 370.422 , meta_l: 1026.57 , addi_l: 3.45706
# Predictions & Answers
# Pred: [ 240.47839355], Actual: [ 69.05583162] -- Input: [ 8.30998385 -1.        ]
# Pred: [ 47.64265442], Actual: [ 11.15705218] -- Input: [ 3.34021739 -1.        ]
# Pred: [ 339.88088989], Actual: [ 58.27354559] -- Input: [ 7.63371113 -1.        ]
# Pred: [ 23.24620819], Actual: [ 3.87475247] -- Input: [ 1.96843909 -1.        ]
# Pred: [ 301.77276611], Actual: [ 61.0570472] -- Input: [ 7.8139009 -1.       ]
# Pred: [ 4525.1171875], Actual: [ 43.23935324] -- Input: [ 6.57566371 -1.        ]
# Pred: [ 7.94846153], Actual: [ 0.17855697] -- Input: [ 0.42256002 -1.        ]
# Pred: [ 37.20219421], Actual: [ 8.22347492] -- Input: [ 2.86766018 -1.        ]
# Pred: [ 348.77050781], Actual: [ 57.75267332] -- Input: [ 7.59951797 -1.        ]
# Pred: [ 11.32212257], Actual: [ 0.68170699] -- Input: [ 0.82565549 -1.        ]
#
# Iteration: 10 , loss: 225.861 , meta_l: 140.571 , addi_l: 3.36311
# Predictions & Answers
# Pred: [ 143.9886322], Actual: [ 60.30562186] -- Input: [ 7.76566944 -1.        ]
# Pred: [ 18.97784805], Actual: [ 2.97856296] -- Input: [ 1.72585137 -1.        ]
# Pred: [ 43.04437637], Actual: [ 9.80156616] -- Input: [ 3.1307453 -1.       ]
# Pred: [ 18.4554081], Actual: [ 2.81974857] -- Input: [ 1.6792107 -1.       ]
# Pred: [ 20.41586304], Actual: [ 3.42031195] -- Input: [ 1.84940854 -1.        ]
# Pred: [ 34.98973083], Actual: [ 7.7526559] -- Input: [ 2.78435916 -1.        ]
# Pred: [ 2913.00585938], Actual: [ 33.34873331] -- Input: [ 5.77483622 -1.        ]
# Pred: [ 147.40907288], Actual: [ 58.78076975] -- Input: [ 7.66686179 -1.        ]
# Pred: [ 114.77722168], Actual: [ 99.21316937] -- Input: [ 9.96058077 -1.        ]
# Pred: [ 116.46913147], Actual: [ 92.23893227] -- Input: [ 9.60411018 -1.        ]
#
# Iteration: 20 , loss: 37.6463 , meta_l: 41.4137 , addi_l: 5.30332
# Predictions & Answers
# Pred: [ 110.0752182], Actual: [ 40.96097385] -- Input: [ 6.40007608 -1.        ]
# Pred: [ 14.81971836], Actual: [ 2.15860506] -- Input: [ 1.4692192 -1.       ]
# Pred: [ 54.9520874], Actual: [ 11.41951695] -- Input: [ 3.37927758 -1.        ]
# Pred: [ 140.02703857], Actual: [ 34.82145694] -- Input: [ 5.90097085 -1.        ]
# Pred: [ 59.84409714], Actual: [ 12.08720873] -- Input: [ 3.47666632 -1.        ]
# Pred: [ 100.98440552], Actual: [ 44.71208553] -- Input: [ 6.68670962 -1.        ]
# Pred: [ 83.14668274], Actual: [ 65.18999184] -- Input: [ 8.07403194 -1.        ]
# Pred: [ 125.24248505], Actual: [ 37.1380523] -- Input: [ 6.09409979 -1.        ]
# Pred: [ 6.70662117], Actual: [ 0.204082] -- Input: [ 0.45175435 -1.        ]
# Pred: [ 79.40209198], Actual: [ 94.07776581] -- Input: [ 9.69936935 -1.        ]
#
# Iteration: 30 , loss: 17.965 , meta_l: 27.7603 , addi_l: 9.79652
# Predictions & Answers
# Pred: [ 11.31558037], Actual: [ 1.54556182] -- Input: [ 1.24320627 -1.        ]
# Pred: [ 55.67894745], Actual: [ 61.26829929] -- Input: [ 7.82740693 -1.        ]
# Pred: [ 59.09212875], Actual: [ 45.37532691] -- Input: [ 6.73612106 -1.        ]
# ...
# Pred: [ 32.99366379], Actual: [ 29.42742919] -- Input: [ 5.42470545 -1.        ]
# Pred: [ 49.37374115], Actual: [ 67.83212637] -- Input: [ 8.23602613 -1.        ]
# Pred: [ 12.61751366], Actual: [ 3.85398008] -- Input: [ 1.96315564 -1.        ]
# Pred: [ 10.38520813], Actual: [ 2.41076675] -- Input: [ 1.5526644 -1.       ]
# Pred: [ 48.07506561], Actual: [ 64.19586564] -- Input: [ 8.01223225 -1.        ]
# Pred: [ 10.99155521], Actual: [ 2.77936251] -- Input: [ 1.66714202 -1.        ]
# Pred: [ 48.96117401], Actual: [ 66.66587388] -- Input: [ 8.16491726 -1.        ]
# Pred: [ 35.23667526], Actual: [ 33.73058004] -- Input: [ 5.80780338 -1.        ]
# Pred: [ 48.54597473], Actual: [ 65.50260179] -- Input: [ 8.09336777 -1.        ]
#
# Iteration: 30 , loss: 12.348 , meta_l: 24.493 , addi_l: 12.4484
# Predictions & Answers
# Pred: [ 41.96346664], Actual: [ 46.44594301] -- Input: [ 6.81512605 -1.        ]
# Pred: [ 46.4469223], Actual: [ 57.20268885] -- Input: [ 7.56324592 -1.        ]
# Pred: [ 22.20515442], Actual: [ 12.60068137] -- Input: [ 3.54974385 -1.        ]
# Pred: [ 15.94501114], Actual: [ 6.3723454] -- Input: [ 2.52435049 -1.        ]
# Pred: [ 15.59270191], Actual: [ 0.19042654] -- Input: [ 0.4363789 -1.       ]
# Pred: [ 54.09455872], Actual: [ 78.19139039] -- Input: [ 8.84258958 -1.        ]
# Pred: [ 8.18368721], Actual: [ 1.28562471] -- Input: [ 1.13385392 -1.        ]
# Pred: [ 45.81544113], Actual: [ 55.61836682] -- Input: [ 7.45777224 -1.        ]
# Pred: [ 16.50475121], Actual: [ 6.85395877] -- Input: [ 2.61800664 -1.        ]
# Pred: [ 41.33108521], Actual: [ 45.02074481] -- Input: [ 6.70974998 -1.        ]
#
# Iteration: 40 , loss: 10.2949 , meta_l: 23.5507 , addi_l: 13.5488
# Predictions & Answers
# Pred: [ 50.37096024], Actual: [ 62.35230896] -- Input: [ 7.89634782 -1.        ]
# Pred: [ 34.81602478], Actual: [ 29.43295673] -- Input: [ 5.4252149 -1.       ]
# Pred: [ 22.36226654], Actual: [ 12.04369307] -- Input: [ 3.47040244 -1.        ]
# Pred: [ 12.16761684], Actual: [ 3.42988213] -- Input: [ 1.85199409 -1.        ]
# Pred: [ 36.92622375], Actual: [ 33.16542667] -- Input: [ 5.75894319 -1.        ]
# Pred: [ 51.69224548], Actual: [ 65.72562609] -- Input: [ 8.10713427 -1.        ]
# Pred: [ 27.616539], Actual: [ 18.41964528] -- Input: [ 4.29181142 -1.        ]
# Pred: [ 29.80875397], Actual: [ 21.49249936] -- Input: [ 4.63600036 -1.        ]
# Pred: [ 60.21826935], Actual: [ 89.66758847] -- Input: [ 9.46929715 -1.        ]
# Pred: [ 2.64111328], Actual: [  4.73377252e-05] -- Input: [ 0.00688024 -1.        ]
#
# Iteration: 50 , loss: 8.80925 , meta_l: 21.634 , addi_l: 13.2432
# Predictions & Answers
# Pred: [ 39.29235458], Actual: [ 38.81583381] -- Input: [ 6.23023545 -1.        ]
# Pred: [ 25.6967144], Actual: [ 16.6507689] -- Input: [ 4.08053537 -1.        ]
# Pred: [ 30.75255013], Actual: [ 23.78088632] -- Input: [ 4.87656501 -1.        ]
# Pred: [ 4.96262026], Actual: [ 0.07150027] -- Input: [ 0.26739534 -1.        ]
# Pred: [ 2.51609349], Actual: [  3.42272601e-05] -- Input: [ 0.00585041 -1.        ]
# Pred: [ 20.64153671], Actual: [ 10.75430184] -- Input: [ 3.27937522 -1.        ]
# Pred: [ 17.8603096], Actual: [ 8.05940906] -- Input: [ 2.83890984 -1.        ]
# Pred: [ 54.53171921], Actual: [ 75.0477933] -- Input: [ 8.66301295 -1.        ]
# Pred: [ 18.6369915], Actual: [ 8.77282359] -- Input: [ 2.96189527 -1.        ]
# Pred: [ 8.13244057], Actual: [ 1.50719479] -- Input: [ 1.22767862 -1.        ]
#
# Iteration: 60 , loss: 10.5252 , meta_l: 25.5681 , addi_l: 15.1913
# Predictions & Answers
# Pred: [ 33.19514847], Actual: [ 26.61773553] -- Input: [ 5.15923788 -1.        ]
# Pred: [ 41.66278076], Actual: [ 41.80258155] -- Input: [ 6.46549159 -1.        ]
# Pred: [ 21.3249321], Actual: [ 11.11085666] -- Input: [ 3.33329517 -1.        ]
# Pred: [ 44.63779068], Actual: [ 47.97132825] -- Input: [ 6.92613372 -1.        ]
# Pred: [ 52.28771591], Actual: [ 65.82673684] -- Input: [ 8.11336779 -1.        ]
# Pred: [ 59.12491989], Actual: [ 84.21544632] -- Input: [ 9.17689742 -1.        ]
# Pred: [ 56.97284317], Actual: [ 78.18000481] -- Input: [ 8.84194576 -1.        ]
# Pred: [ 24.55233955], Actual: [ 14.6678323] -- Input: [ 3.82986061 -1.        ]
# Pred: [ 35.6517067], Actual: [ 30.6616771] -- Input: [ 5.53729872 -1.        ]
# Pred: [ 47.49502945], Actual: [ 54.30442773] -- Input: [ 7.3691538 -1.       ]
#
# Iteration: 70 , loss: 6.11259 , meta_l: 20.4774 , addi_l: 14.1973
# Predictions & Answers
# Pred: [ 15.73313141], Actual: [ 6.58540536] -- Input: [ 2.56620447 -1.        ]
# Pred: [ 6.18104076], Actual: [ 0.09629742] -- Input: [ 0.31031826 -1.        ]
# Pred: [ 41.3885498], Actual: [ 43.08039835] -- Input: [ 6.56356598 -1.        ]
# Pred: [ 39.43428802], Actual: [ 39.16531667] -- Input: [ 6.25821993 -1.        ]
# Pred: [ 14.38475513], Actual: [ 5.55602926] -- Input: [ 2.35712309 -1.        ]
# Pred: [ 42.20758057], Actual: [ 44.77796736] -- Input: [ 6.69163413 -1.        ]
# Pred: [ 24.8801384], Actual: [ 15.87177735] -- Input: [ 3.98393993 -1.        ]
# Pred: [ 17.46038055], Actual: [ 8.02859218] -- Input: [ 2.83347705 -1.        ]
# Pred: [ 4.11088324], Actual: [ 0.05099823] -- Input: [ 0.22582788 -1.        ]
# Pred: [ 5.69695282], Actual: [ 0.46278099] -- Input: [ 0.68028009 -1.        ]
#
# Iteration: 80 , loss: 11.732 , meta_l: 29.1835 , addi_l: 17.7388
# Predictions & Answers
# Pred: [ 60.58590317], Actual: [ 80.17091142] -- Input: [ 8.95382105 -1.        ]
# Pred: [ 18.11663246], Actual: [ 7.7205443] -- Input: [ 2.77858674 -1.        ]
# Pred: [ 51.63072205], Actual: [ 58.35952171] -- Input: [ 7.6393404 -1.       ]
# Pred: [ 5.87586117], Actual: [ 0.64950596] -- Input: [ 0.80591932 -1.        ]
# Pred: [ 57.58194733], Actual: [ 72.46367854] -- Input: [ 8.51256005 -1.        ]
# Pred: [ 48.97636414], Actual: [ 52.56794967] -- Input: [ 7.25037583 -1.        ]
# Pred: [ 58.50186539], Actual: [ 74.78197997] -- Input: [ 8.64765748 -1.        ]
# Pred: [ 48.10074234], Actual: [ 50.72495249] -- Input: [ 7.12214522 -1.        ]
# Pred: [ 60.0605278], Actual: [ 78.79448196] -- Input: [ 8.8766256 -1.       ]
# Pred: [ 34.68455124], Actual: [ 26.67097214] -- Input: [ 5.16439465 -1.        ]
#
# Iteration: 90 , loss: 8.7575 , meta_l: 25.8461 , addi_l: 17.2921
# Predictions & Answers
# Pred: [ 51.90003204], Actual: [ 56.81608386] -- Input: [ 7.53764445 -1.        ]
# Pred: [ 56.39247131], Actual: [ 66.92337668] -- Input: [ 8.18067092 -1.        ]
# Pred: [ 54.09976196], Actual: [ 61.66022115] -- Input: [ 7.85240225 -1.        ]
# Pred: [ 11.65020561], Actual: [ 3.25061185] -- Input: [ 1.80294533 -1.        ]
# Pred: [ 19.51622963], Actual: [ 8.67124601] -- Input: [ 2.94469795 -1.        ]
# Pred: [ 14.72141075], Actual: [ 5.0711057] -- Input: [ 2.25191157 -1.        ]
# Pred: [ 20.96387672], Actual: [ 9.94680268] -- Input: [ 3.15385521 -1.        ]
# Pred: [ 43.68263626], Actual: [ 40.5002663] -- Input: [ 6.36398195 -1.        ]
# Pred: [ 44.51567459], Actual: [ 42.02641037] -- Input: [ 6.48277798 -1.        ]
# Pred: [ 6.14741325], Actual: [ 0.08680935] -- Input: [ 0.29463426 -1.        ]
#
#
#
# Iteration: 10. Next problem: mult.
#
# Iteration: 0 , loss: 18.9411 , meta_l: 28.1969 , addi_l: 9.96565
# Predictions & Answers
# Pred: [ 49.51286316], Actual: [ 30.10745253] -- Input: [ 6.02149051  1.        ]
# Pred: [ 63.41049194], Actual: [ 40.16345131] -- Input: [ 8.03269026  1.        ]
# Pred: [ 50.24097443], Actual: [ 30.6357416] -- Input: [ 6.12714832  1.        ]
# Pred: [ 40.60655975], Actual: [ 23.62212763] -- Input: [ 4.72442553  1.        ]
# Pred: [ 66.96338654], Actual: [ 42.7279065] -- Input: [ 8.5455813  1.       ]
# Pred: [ 11.61376572], Actual: [ 0.05115926] -- Input: [ 0.01023185  1.        ]
# Pred: [ 26.79381752], Actual: [ 13.33899622] -- Input: [ 2.66779924  1.        ]
# Pred: [ 70.03096008], Actual: [ 44.94077229] -- Input: [ 8.98815446  1.        ]
# Pred: [ 28.05578995], Actual: [ 14.32091873] -- Input: [ 2.86418375  1.        ]
# Pred: [ 76.6319046], Actual: [ 49.69942205] -- Input: [ 9.93988441  1.        ]
#
# Iteration: 10 , loss: 11.4193 , meta_l: 19.2179 , addi_l: 8.25396
# Predictions & Answers
# Pred: [ 62.19801712], Actual: [ 48.20852431] -- Input: [ 9.64170486  1.        ]
# Pred: [ 38.71693039], Actual: [ 27.59509625] -- Input: [ 5.51901925  1.        ]
# Pred: [ 49.96510696], Actual: [ 37.49356239] -- Input: [ 7.49871248  1.        ]
# Pred: [ 62.34404373], Actual: [ 48.33626592] -- Input: [ 9.66725318  1.        ]
# Pred: [ 51.44571304], Actual: [ 38.79231402] -- Input: [ 7.7584628  1.       ]
# Pred: [ 53.59962845], Actual: [ 40.68056771] -- Input: [ 8.13611354  1.        ]
# Pred: [ 37.90037537], Actual: [ 26.87325402] -- Input: [ 5.3746508  1.       ]
# Pred: [ 30.02339172], Actual: [ 19.86609695] -- Input: [ 3.97321939  1.        ]
# Pred: [ 41.36422729], Actual: [ 29.93145092] -- Input: [ 5.98629018  1.        ]
# Pred: [ 23.69990349], Actual: [ 14.13310736] -- Input: [ 2.82662147  1.        ]
#
# Iteration: 20 , loss: 5.23873 , meta_l: 15.2789 , addi_l: 10.3399
# Predictions & Answers
# Pred: [ 39.55525208], Actual: [ 35.24925352] -- Input: [ 7.0498507  1.       ]
# Pred: [ 11.4435873], Actual: [ 4.18048329] -- Input: [ 0.83609666  1.        ]
# Pred: [ 29.46191216], Actual: [ 24.52856107] -- Input: [ 4.90571221  1.        ]
# Pred: [ 18.84736061], Actual: [ 12.98721036] -- Input: [ 2.59744207  1.        ]
# Pred: [ 41.80897522], Actual: [ 37.63101147] -- Input: [ 7.52620229  1.        ]
# Pred: [ 23.83554459], Actual: [ 18.47371023] -- Input: [ 3.69474205  1.        ]
# Pred: [ 51.27112198], Actual: [ 47.6073652] -- Input: [ 9.52147304  1.        ]
# Pred: [ 21.69434929], Actual: [ 16.13833774] -- Input: [ 3.22766755  1.        ]
# Pred: [ 13.34755421], Actual: [ 6.59400246] -- Input: [ 1.31880049  1.        ]
# Pred: [ 20.63252831], Actual: [ 14.97038426] -- Input: [ 2.99407685  1.        ]
#
# Iteration: 30 , loss: 2.26407 , meta_l: 23.2325 , addi_l: 21.2169
# Predictions & Answers
# Pred: [ 35.80526352], Actual: [ 36.37594667] -- Input: [ 7.27518933  1.        ]
# Pred: [ 20.25970268], Actual: [ 17.53494044] -- Input: [ 3.50698809  1.        ]
# Pred: [ 13.42678833], Actual: [ 8.82627524] -- Input: [ 1.76525505  1.        ]
# Pred: [ 36.74803925], Actual: [ 37.50628257] -- Input: [ 7.50125651  1.        ]
# Pred: [ 24.06481171], Actual: [ 22.20608244] -- Input: [ 4.44121649  1.        ]
# Pred: [ 39.35585403], Actual: [ 40.62981599] -- Input: [ 8.1259632  1.       ]
# Pred: [ 38.81993103], Actual: [ 39.98823924] -- Input: [ 7.99764785  1.        ]
# Pred: [ 7.82107592], Actual: [ 0.51697056] -- Input: [ 0.10339411  1.        ]
# Pred: [ 19.7539463], Actual: [ 16.90813188] -- Input: [ 3.38162638  1.        ]
# Pred: [ 44.82260132], Actual: [ 47.16660773] -- Input: [ 9.43332155  1.        ]
#
# Iteration: 40 , loss: 1.59875 , meta_l: 15.3219 , addi_l: 13.9536
# Predictions & Answers
# Pred: [ 29.32276344], Actual: [ 28.53552118] -- Input: [ 5.70710424  1.        ]
# Pred: [ 28.96344185], Actual: [ 28.10641118] -- Input: [ 5.62128224  1.        ]
# Pred: [ 31.55861664], Actual: [ 31.20115883] -- Input: [ 6.24023177  1.        ]
# Pred: [ 27.73386955], Actual: [ 26.63621464] -- Input: [ 5.32724293  1.        ]
# Pred: [ 26.737957], Actual: [ 25.44316342] -- Input: [ 5.08863268  1.        ]
# Pred: [ 33.14687347], Actual: [ 33.09070125] -- Input: [ 6.61814025  1.        ]
# Pred: [ 22.68932724], Actual: [ 20.56494521] -- Input: [ 4.11298904  1.        ]
# Pred: [ 9.68946552], Actual: [ 3.77275046] -- Input: [ 0.75455009  1.        ]
# Pred: [ 45.96795273], Actual: [ 48.27373729] -- Input: [ 9.65474746  1.        ]
# Pred: [ 33.04790878], Actual: [ 32.97304995] -- Input: [ 6.59460999  1.        ]
#
# Iteration: 50 , loss: 2.77539 , meta_l: 24.8298 , addi_l: 22.1443
# Predictions & Answers
# Pred: [ 15.21359634], Actual: [ 11.40897591] -- Input: [ 2.28179518  1.        ]
# Pred: [ 9.52027321], Actual: [ 3.7008086] -- Input: [ 0.74016172  1.        ]
# Pred: [ 21.95611191], Actual: [ 19.70263975] -- Input: [ 3.94052795  1.        ]
# Pred: [ 9.54658699], Actual: [ 3.74013629] -- Input: [ 0.74802726  1.        ]
# Pred: [ 10.12878513], Actual: [ 4.59696995] -- Input: [ 0.91939399  1.        ]
# Pred: [ 22.02750397], Actual: [ 19.78865514] -- Input: [ 3.95773103  1.        ]
# Pred: [ 13.61613083], Actual: [ 9.35795902] -- Input: [ 1.8715918  1.       ]
# Pred: [ 24.87445259], Actual: [ 23.20183793] -- Input: [ 4.64036759  1.        ]
# Pred: [ 34.76116943], Actual: [ 34.90374965] -- Input: [ 6.98074993  1.        ]
# Pred: [ 34.07033539], Actual: [ 34.09059575] -- Input: [ 6.81811915  1.        ]
#
# Iteration: 60 , loss: 2.42951 , meta_l: 13.3014 , addi_l: 10.9438
# Predictions & Answers
# Pred: [ 26.26855469], Actual: [ 24.48832706] -- Input: [ 4.89766541  1.        ]
# Pred: [ 13.47848225], Actual: [ 9.12562274] -- Input: [ 1.82512455  1.        ]
# Pred: [ 36.38088989], Actual: [ 36.17369164] -- Input: [ 7.23473833  1.        ]
# Pred: [ 32.01432419], Actual: [ 31.14549577] -- Input: [ 6.22909915  1.        ]
# Pred: [ 15.97176838], Actual: [ 12.24963011] -- Input: [ 2.44992602  1.        ]
# Pred: [ 12.13611794], Actual: [ 7.38246747] -- Input: [ 1.47649349  1.        ]
# Pred: [ 14.1683712], Actual: [ 10.00246912] -- Input: [ 2.00049382  1.        ]
# Pred: [ 42.7725296], Actual: [ 43.50686018] -- Input: [ 8.70137204  1.        ]
# Pred: [ 24.09557724], Actual: [ 21.95104826] -- Input: [ 4.39020965  1.        ]
# Pred: [ 12.13065052], Actual: [ 7.3752566] -- Input: [ 1.47505132  1.        ]
#
# Iteration: 70 , loss: 2.91725 , meta_l: 22.6437 , addi_l: 19.562
# Predictions & Answers
# Pred: [ 42.60535431], Actual: [ 43.7405667] -- Input: [ 8.74811334  1.        ]
# Pred: [ 13.84544277], Actual: [ 9.93099878] -- Input: [ 1.98619976  1.        ]
# Pred: [ 24.92976761], Actual: [ 23.29138414] -- Input: [ 4.65827683  1.        ]
# Pred: [ 10.05521774], Actual: [ 4.88239173] -- Input: [ 0.97647835  1.        ]
# Pred: [ 14.1015749], Actual: [ 10.25566959] -- Input: [ 2.05113392  1.        ]
# Pred: [ 39.84641266], Actual: [ 40.56858971] -- Input: [ 8.11371794  1.        ]
# Pred: [ 45.78034592], Actual: [ 47.38649759] -- Input: [ 9.47729952  1.        ]
# Pred: [ 13.05081749], Actual: [ 8.913973] -- Input: [ 1.7827946  1.       ]
# Pred: [ 41.32797241], Actual: [ 42.2724456] -- Input: [ 8.45448912  1.        ]
# Pred: [ 19.25110435], Actual: [ 16.57105422] -- Input: [ 3.31421084  1.        ]
#
# Iteration: 80 , loss: 2.25349 , meta_l: 21.1765 , addi_l: 18.8042
# Predictions & Answers
# Pred: [ 22.69771385], Actual: [ 20.62284936] -- Input: [ 4.12456987  1.        ]
# Pred: [ 38.75156784], Actual: [ 39.19166051] -- Input: [ 7.8383321  1.       ]
# Pred: [ 40.5981636], Actual: [ 41.30802968] -- Input: [ 8.26160594  1.        ]
# Pred: [ 23.35744667], Actual: [ 21.39724159] -- Input: [ 4.27944832  1.        ]
# Pred: [ 47.61086655], Actual: [ 49.32998281] -- Input: [ 9.86599656  1.        ]
# Pred: [ 26.70432854], Actual: [ 25.30312866] -- Input: [ 5.06062573  1.        ]
# Pred: [ 7.96642065], Actual: [ 1.80850811] -- Input: [ 0.36170162  1.        ]
# Pred: [ 45.39476013], Actual: [ 46.79709723] -- Input: [ 9.35941945  1.        ]
# Pred: [ 27.03815269], Actual: [ 25.6910053] -- Input: [ 5.13820106  1.        ]
# Pred: [ 10.65256023], Actual: [ 5.74574185] -- Input: [ 1.14914837  1.        ]
#
# Iteration: 90 , loss: 2.37463 , meta_l: 14.712 , addi_l: 12.4665
# Predictions & Answers
# Pred: [ 44.77850342], Actual: [ 47.16553528] -- Input: [ 9.43310706  1.        ]
# Pred: [ 18.73555946], Actual: [ 16.55625028] -- Input: [ 3.31125006  1.        ]
# Pred: [ 44.88129425], Actual: [ 47.28485896] -- Input: [ 9.45697179  1.        ]
# Pred: [ 26.2566433], Actual: [ 25.53723006] -- Input: [ 5.10744601  1.        ]
# Pred: [ 33.73232269], Actual: [ 34.30910395] -- Input: [ 6.86182079  1.        ]
# Pred: [ 7.58758307], Actual: [ 1.72577954] -- Input: [ 0.34515591  1.        ]
# Pred: [ 8.14607525], Actual: [ 2.61455279] -- Input: [ 0.52291056  1.        ]
# Pred: [ 17.36611176], Actual: [ 14.88580628] -- Input: [ 2.97716126  1.        ]
# Pred: [ 34.71170425], Actual: [ 35.45263679] -- Input: [ 7.09052736  1.        ]
# Pred: [ 27.73794174], Actual: [ 27.28319385] -- Input: [ 5.45663877  1.        ]
